# %%
import pandas as pd

# %%
iforest_001_allfeat = pd.read_csv("test_result_iforest_001_allfeat.csv", encoding="utf8",low_memory = False)
iforest_001_ipca = pd.read_csv("test_result_iforest_001_ipca.csv", encoding="utf8",low_memory = False)
iforest_001_var = pd.read_csv("test_result_iforest_001_var.csv", encoding="utf8",low_memory = False)

# %%
iforest_001_allfeat['conversations'] = iforest_001_allfeat[['source_ip','destination_ip']].apply(lambda k: '->'.join(k),axis=1)
iforest_001_allfeat.conversations.value_counts().head(20)
# Out:
# conversations
# 55.152.238.8->1.38.26.35       1
# 64.94.1.172->150.233.152.80    1
# Name: count, dtype: int64

# %%
iforest_001_allfeat.state.value_counts()[:10].plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
iforest_001_ipca['conversations'] = iforest_001_ipca[['source_ip','destination_ip']].apply(lambda k: '->'.join(k),axis=1)
iforest_001_ipca.source_ip.value_counts().head(60)
# Out:
# source_ip
# 55.152.238.8       1
# 203.129.191.213    1
# 159.29.79.65       1
# 64.94.1.172        1
# Name: count, dtype: int64

# %%
iforest_001_ipca.destination_ip.value_counts()[:15].plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
iforest_001_var['conversations'] = iforest_001_var[['source_ip','destination_ip']].apply(lambda k: '->'.join(k),axis=1)
iforest_001_var.source_ip.value_counts()
# Out:
# source_ip
# 55.152.238.8      1
# 39.202.135.152    1
# 64.94.1.172       1
# Name: count, dtype: int64

# %%
iforest_001_var.conversations.value_counts()[:15].plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
iforest_002_allfeat = pd.read_csv("test_result_iforest_001_allfeat.csv", encoding="utf8",low_memory = False)
iforest_002_ipca = pd.read_csv("test_result_iforest_001_ipca.csv", encoding="utf8",low_memory = False)
iforest_002_var = pd.read_csv("test_result_iforest_001_var.csv", encoding="utf8",low_memory = False)

# %%
iforest_001_allfeat.conversations.value_counts()[:15].plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
iforest_002_ipca['conversations'] = iforest_001_ipca[['source_ip','destination_ip']].apply(lambda k: '->'.join(k),axis=1)
iforest_002_ipca.source_ip.value_counts().head(30)
# Out:
# source_ip
# 55.152.238.8       1
# 203.129.191.213    1
# 159.29.79.65       1
# 64.94.1.172        1
# Name: count, dtype: int64

# %%
iforest_001_ipca.conversations.value_counts()[:15].plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
iforest_001_var['conversations'] = iforest_002_var[['source_ip','destination_ip']].apply(lambda k: '->'.join(k),axis=1)
iforest_001_var.conversations.value_counts()[:15]
# Out:
# conversations
# 55.152.238.8->1.38.26.35         1
# 39.202.135.152->176.62.38.137    1
# 64.94.1.172->150.233.152.80      1
# Name: count, dtype: int64

# %%
iforest_001_var.destination_ip.value_counts()[:15].plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
iforest_01_allfeat = pd.read_csv("test_result_iforest_001_allfeat.csv", encoding="utf8",low_memory = False)
iforest_01_ipca = pd.read_csv("test_result_iforest_001_ipca.csv", encoding="utf8",low_memory = False)
iforest_01_var = pd.read_csv("test_result_iforest_001_var.csv", encoding="utf8",low_memory = False)

# %%
iforest_01_allfeat['conversations'] = iforest_01_allfeat[['source_ip','destination_ip']].apply(lambda k: '->'.join(k),axis=1)
iforest_01_allfeat.conversations.value_counts()[:15]
# Out:
# conversations
# 55.152.238.8->1.38.26.35       1
# 64.94.1.172->150.233.152.80    1
# Name: count, dtype: int64

# %%
iforest_01_allfeat.conversations.value_counts()[:15].plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
iforest_01_ipca['conversations'] = iforest_01_ipca[['source_ip','destination_ip']].apply(lambda k: '->'.join(k),axis=1)
iforest_01_ipca.conversations.value_counts()[:15]
# Out:
# conversations
# 55.152.238.8->1.38.26.35            1
# 203.129.191.213->255.254.164.115    1
# 159.29.79.65->240.37.224.45         1
# 64.94.1.172->150.233.152.80         1
# Name: count, dtype: int64

# %%
iforest_01_ipca.conversations.value_counts()[:15].plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
iforest_01_var['conversations'] = iforest_01_var[['source_ip','destination_ip']].apply(lambda k: '->'.join(k),axis=1)
iforest_01_var.conversations.value_counts()[:15]
# Out:
# conversations
# 55.152.238.8->1.38.26.35         1
# 39.202.135.152->176.62.38.137    1
# 64.94.1.172->150.233.152.80      1
# Name: count, dtype: int64

# %%
iforest_01_var.conversations.value_counts()[:15].plot.pie()
# Out:
# <Axes: ylabel='count'>
